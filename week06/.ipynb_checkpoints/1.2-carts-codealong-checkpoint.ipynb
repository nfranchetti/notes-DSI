# %% [markdown]
# # Decision Trees Lab
#
# In this lab we will discover how to apply decision trees to regression and classification problems.

# %% [markdown]
# ### 1: Build a regression tree
#
# How do you build a decision tree? You're going to find out by building one in pairs!
#
# Your training data is a tiny dataset of [used vehicle sale prices](../../assets/datasets/used_cars.csv). Your goal is to predict Price for out-of-sample data. Here are your instructions:
#
# 1. Read the data into Pandas.
# - Explore the data by sorting, plotting, or split-apply-combine (aka `group_by`).
# - Decide which feature is the most important predictor, and use that to make your first split. (Only binary splits are allowed!)
# - After making your first split, you should actually split your data in Pandas into two parts, and then explore each part to figure out what other splits to make.
# - Decide if you need additional splits along other features
# - Stop making splits once you are convinced that it strikes a good balance between underfitting and overfitting. (As always, your goal is to build a model that generalizes well!)
# - You are allowed to split on the same variable multiple times!
# - Draw your tree on a piece of paper, making sure to label your leaves with the mean Price for the observations in that "bucket".
# - When you're finished, review your tree to make sure nothing is backwards. (Remember: follow the left branch if the rule is true, and follow the right branch if the rule is false.)

# %%
import pandas as pd

data = pd.read_csv('../../DSI-CHI-1/lessons/week-06/1.2-carts-codealong/assets/datasets/used_cars.csv')
data
# Out:
#     price  year   miles  doors   type
# 0   22000  2012   13000      2    car
# 1   14000  2010   30000      2    car
# 2   13000  2010   73500      4    car
# 3    9500  2009   78000      4    car
# 4    9000  2007   47000      4    car
# 5    4000  2006  124000      2    car
# 6    3000  2004  177000      4    car
# 7    2000  2004  209000      4  truck
# 8    3000  2003  138000      2    car
# 9    1900  2003  160000      4    car
# 10   2500  2003  190000      2  truck
# 11   5000  2001   62000      4    car
# 12   1800  1999  163000      2  truck
# 13   1300  1997  138000      4    car

# %%
data.describe()
# Out:
#               price         year          miles      doors
# count     14.000000    14.000000      14.000000  14.000000
# mean    6571.428571  2004.857143  114464.285714   3.142857
# std     6161.097376     4.382784   63198.242516   1.027105
# min     1300.000000  1997.000000   13000.000000   2.000000
# 25%     2125.000000  2003.000000   64875.000000   2.000000
# 50%     3500.000000  2004.000000  131000.000000   4.000000
# 75%     9375.000000  2008.500000  162250.000000   4.000000
# max    22000.000000  2012.000000  209000.000000   4.000000

# %%
data['doors'].value_counts()
# Out:
# 4    8
# 2    6
# Name: doors, dtype: int64

# %%
data['type'].value_counts()
# Out:
# car      11
# truck     3
# Name: type, dtype: int64

# %% [markdown]
# #### How does a computer build a regression tree?
#
# The ideal approach would be for the computer to consider every possible partition of the feature space. However, this is computationally infeasible, so instead an approach is used called **recursive binary splitting:**
#
# - Begin at the top of the tree.
# - For every single predictor, examine every possible cutpoint, and choose the predictor and cutpoint such that the resulting tree has the **lowest possible mean squared error (MSE)**. Make that split.
# - Repeat the examination for the two resulting regions, and again make a single split (in one of the regions) to minimize the MSE.
# - Keep repeating this process until a stopping criteria is met.
#
# **How does it know when to stop?**
#
# 1. We could define a stopping criterion, such as a **maximum depth** of the tree or the **minimum number of samples in the leaf**.
# 2. We could grow the tree deep, and then "prune" it back using a method such as "cost complexity pruning" (aka "weakest link pruning").
#
# Method 2 involves setting a tuning parameter that penalizes the tree for having too many leaves. As the parameter is increased, branches automatically get pruned from the tree, resulting in smaller and smaller trees. The tuning parameter can be selected through cross-validation.
#
# Note: **Method 2 is not currently supported by scikit-learn**, and so we will use Method 1 instead.

# %% [markdown]
# ### 2: Build a regression tree in scikit-learn
#
# Building a tree by hand was not so easy, and also not ideal. Let's use scikit-learn to build an optimal regression tree. Do the following:
#
# - Map the `type` column to a binary variable
# - Create a matrix `X` that contains the feature values and a vector `y` that contains the price values
# - Split the data into train-test using a random state of 42 and test_size of 30%
# - Import and initialize the `DecisionTreeRegressor` class from scikit-learn
# - Fit it to the training set
# - Predict the values of the test set
# - Display the predicted and actual values in a plot
# - Use r2_score to judge the goodness of the regression

# %%
data['is_car'] = data['type'].apply(lambda x: 1 if x == 'car' else 0)
data
# Out:
#     price  year   miles  doors   type  is_car
# 0   22000  2012   13000      2    car       1
# 1   14000  2010   30000      2    car       1
# 2   13000  2010   73500      4    car       1
# 3    9500  2009   78000      4    car       1
# 4    9000  2007   47000      4    car       1
# 5    4000  2006  124000      2    car       1
# 6    3000  2004  177000      4    car       1
# 7    2000  2004  209000      4  truck       0
# 8    3000  2003  138000      2    car       1
# 9    1900  2003  160000      4    car       1
# 10   2500  2003  190000      2  truck       0
# 11   5000  2001   62000      4    car       1
# 12   1800  1999  163000      2  truck       0
# 13   1300  1997  138000      4    car       1

# %%
y = data['price']
X = data[['year', 'miles', 'doors', 'is_car']]

# %%
from sklearn.cross_validation import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=42, test_size=0.3)

# %%
print X_train.shape, X_test.shape, y_train.shape, y_test.shape
# Out:
# (9, 4) (5, 4) (9,) (5,)

# %%
from sklearn.tree import DecisionTreeRegressor
decision_tree = DecisionTreeRegressor()

# %%
decision_tree_model = decision_tree.fit(X_train, y_train)
decision_tree_model
# Out:
# DecisionTreeRegressor(criterion='mse', max_depth=None, max_features=None,
#            max_leaf_nodes=None, min_samples_leaf=1, min_samples_split=2,
#            min_weight_fraction_leaf=0.0, presort=False, random_state=None,
#            splitter='best')

# %%
decision_tree.predict(X_train)
# Out:
# array([  3000.,  13000.,  14000.,   1300.,   9000.,   2000.,   2500.,
#          9500.,   3000.])

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

plt.scatter(y_train, decision_tree.predict(X_train))

# %%
from sklearn.metrics import r2_score
r2_score(y_train, decision_tree.predict(X_train))
# Out:
# 1.0

# %%
decision_tree_predictions = decision_tree.predict(X_test)

plt.scatter(y_test, decision_tree_predictions)
plt.plot(y_test, y_test)
plt.ylim((0,25000))
plt.xlim((0,25000))
# Out:
# (0, 25000)

# %% [markdown]
# ### 3.b Global parameters
#
# The `DecisionTreeRegressor` offers few global parameters that can be changed at initialization. For example one can set the `max_depth` or the `min_samples_leaf` parameters and impose global constraints on the space of solutions.
#
# 1. Use `cross_val_score` with 3-fold cross validation to find the optimal value for the `max_depth` (explore values 1 - 10). Note that you will have to set `scoring='mean_squared_error'` as criterion for score. Always set `random_state=1`
# - Plot the error as a function of `max_depth`

# %%
import numpy as np

def find_mse(y_true, y_pred):
    values = []
    for value in zip(y_true, y_pred):
        values.append((value[0]-value[1])**2)
    return np.mean(values)

find_mse(y_test, decision_tree_predictions)
# Out:
# 16492000.0

# %%
def make_pretty_plots(y_true, y_pred, x):
    plt.scatter(y_true, y_pred)
    plt.plot(y_true, y_true)
    plt.ylim((0,25000))
    plt.xlim((0,25000))
    plt.title('max_depth = %i' % x)
    plt.show()

# %%
list_of_mse = []

for x in range(1, 11):
    new_decision_tree = DecisionTreeRegressor(max_depth=x)
    new_decision_tree.fit(X_train, y_train)
    predictions = new_decision_tree.predict(X_test)
    make_pretty_plots(y_test, predictions, x)
    mse = find_mse(y_test, predictions)
    list_of_mse.append(mse)

# %%
list_of_mse
# Out:
# [34955210.0,
#  18595750.0,
#  18892000.0,
#  16492000.0,
#  18892000.0,
#  16492000.0,
#  16492000.0,
#  16492000.0,
#  18892000.0,
#  16492000.0]

# %%
plt.scatter(range(1,11), list_of_mse)
plt.xlabel('max_depth')
plt.ylabel('MSE')

# %% [markdown]
# ## 3.c Feature importances
#
# The decision tree class exposes an attribute called `feature_importances_`.
#
# 1. Check the importance of each feature. what's the most important feature?

# %%
decision_tree.feature_importances_
# Out:
# array([ 0.09728871,  0.90271129,  0.        ,  0.        ])

# %% [markdown]
# ### 3.d Tree visualization
#
# Follow the example in the [documentation](http://scikit-learn.org/stable/modules/tree.html) to visualize the tree.
# You may have to install `pydot` and/or `graphviz` if you don't have them already.

# %%
from IPython.display import Image
import pydot
import sklearn.tree as tree

# %%
feature_names = ['year', 'miles', 'doors', 'is_car']

dot_data = tree.export_graphviz(decision_tree, out_file='test.dot', 
                                feature_names=feature_names,    
                                filled=True, rounded=True,  
                                special_characters=True)  
# graph = pydot.graph_from_dot_data(dot_data)  
# Image(graph.create_png())

# %%
feature_names = ['year', 'miles', 'doors', 'is_car']

from IPython.display import Image
from sklearn.tree import export_graphviz
from sklearn.externals.six import StringIO
import pydot
dot_data = StringIO()  
export_graphviz(decision_tree, out_file=dot_data,  
                feature_names=feature_names,  
                filled=True, rounded=True,  
                special_characters=True)  
graph = pydot.graph_from_dot_data(dot_data.getvalue())  
Image(graph.create_png())

# %% [markdown]
# #### Interpreting a tree diagram
#
# How do we read this decision tree?
#
# **Internal nodes:**
#
# - `samples` is the number of observations in that node before splitting
# - `mse` is the mean squared error calculated by comparing the actual response values in that node against the mean response value in that node
# - First line is the condition used to split that node (go left if true, go right if false)
#
# **Leaves:**
#
# - `samples` is the number of observations in that node
# - `value` is the mean response value in that node
# - `mse` is the mean squared error calculated by comparing the actual response values in that node against "value"

# %% [markdown]
# ### Exercise 4: Use GridSearchCV to find the best Regression Tree
#
# How do we know by pruning with max depth is the best model for us? Trees offer a variety of ways to pre-prune (that is, we tell a computer how to design the resulting tree with certain "gotchas").
#
# Measure           | What it does
# ------------------|-------------
# max_depth         | How many nodes deep can the decision tree go?
# max_features      | Is there a cut off to the number of features to use?
# max_leaf_nodes    | How many leaves can be generated per node?
# min_samples_leaf  | How many samples need to be included at a leaf, at a minimum?
# min_samples_split | How many samples need to be included at a node, at a minimum?
#
# 1. Initialize reasonable ranges for all parameters and find the optimal combination using Grid Search.

# %%
from sklearn.grid_search import GridSearchCV

params = {'max_depth': [1, 2, 3, 4],
          'max_features': [1, 2, 3, 4],
          'max_leaf_nodes': [2, 3, 5]        
         }

# %%
grid_search = GridSearchCV(estimator=DecisionTreeRegressor(), param_grid=params, verbose=10)
grid_search.fit(X_train, y_train)
# Out:
# Fitting 3 folds for each of 48 candidates, totalling 144 fits
# [CV] max_features=1, max_leaf_nodes=2, max_depth=1 ...................
# [CV]  max_features=1, max_leaf_nodes=2, max_depth=1, score=0.496419 -   0.0s
# [CV] max_features=1, max_leaf_nodes=2, max_depth=1 ...................
# [CV]  max_features=1, max_leaf_nodes=2, max_depth=1, score=0.639456 -   0.0s
# [CV] max_features=1, max_leaf_nodes=2, max_depth=1 ...................
# [CV]  max_features=1, max_leaf_nodes=2, max_depth=1, score=0.084354 -   0.0s
# [CV] max_features=1, max_leaf_nodes=3, max_depth=1 ...................
# [CV]  max_features=1, max_leaf_nodes=3, max_depth=1, score=0.552162 -   0.0s
# [CV] max_features=1, max_leaf_nodes=3, max_depth=1 ...................
# [CV]  max_features=1, max_leaf_nodes=3, max_depth=1, score=0.776391 -   0.0s
# [CV] max_features=1, max_leaf_nodes=3, max_depth=1 ...................
# [CV]  max_features=1, max_leaf_nodes=3, max_depth=1, score=0.894426 -   0.0s
# [CV] max_features=1, max_leaf_nodes=5, max_depth=1 ...................
# [CV]  max_features=1, max_leaf_nodes=5, max_depth=1, score=0.486858 -   0.0s
# [CV] max_features=1, max_leaf_nodes=5, max_depth=1 ...................
# [CV]  max_features=1, max_leaf_nodes=5, max_depth=1, score=0.753103 -   0.0s
# [CV] max_features=1, max_leaf_nodes=5, max_depth=1 ...................
# [CV]  max_features=1, max_leaf_nodes=5, max_depth=1, score=0.467213 -   0.0s
# [CV] max_features=2, max_leaf_nodes=2, max_depth=1 ...................
# [CV]  max_features=2, max_leaf_nodes=2, max_depth=1, score=0.496419 -   0.0s
# [CV] max_features=2, max_leaf_nodes=2, max_depth=1 ...................
# [CV]  max_features=2, max_leaf_nodes=2, max_depth=1, score=-0.443464 -   0.0s
# [CV] max_features=2, max_leaf_nodes=2, max_depth=1 ...................
# [CV]  max_features=2, max_leaf_nodes=2, max_depth=1, score=0.763279 -   0.0s
# [CV] max_features=2, max_leaf_nodes=3, max_depth=1 ...................
# [CV]  max_features=2, max_leaf_nodes=3, max_depth=1, score=0.495304 -   0.0s
# [CV] max_features=2, max_leaf_nodes=3, max_depth=1 ...................
# [CV]  max_features=2, max_leaf_nodes=3, max_depth=1, score=0.909113 -   0.0s
# [CV] max_features=2, max_leaf_nodes=3, max_depth=1 ...................
# [CV]  max_features=2, max_leaf_nodes=3, max_depth=1, score=0.894426 -   0.0s
# [CV] max_features=2, max_leaf_nodes=5, max_depth=1 ...................
# [CV]  max_features=2, max_leaf_nodes=5, max_depth=1, score=0.457568 -   0.0s
# [CV] max_features=2, max_leaf_nodes=5, max_depth=1 ...................
# [CV]  max_features=2, max_leaf_nodes=5, max_depth=1, score=0.636851 -   0.0s
# [CV] max_features=2, max_leaf_nodes=5, max_depth=1 ...................
# [CV]  max_features=2, max_leaf_nodes=5, max_depth=1, score=0.467213 -   0.0s
# [CV] max_features=3, max_leaf_nodes=2, max_depth=1 ...................
# [CV]  max_features=3, max_leaf_nodes=2, max_depth=1, score=0.496419 -   0.0s
# [CV] max_features=3, max_leaf_nodes=2, max_depth=1 ...................
# [CV]  max_features=3, max_leaf_nodes=2, max_depth=1, score=0.639456 -   0.0s
# [CV] max_features=3, max_leaf_nodes=2, max_depth=1 ...................
# [CV]  max_features=3, max_leaf_nodes=2, max_depth=1, score=0.763279 -   0.0s
# [CV] max_features=3, max_leaf_nodes=3, max_depth=1 ...................
# [CV]  max_features=3, max_leaf_nodes=3, max_depth=1, score=0.466014 -   0.0s
# [CV] max_features=3, max_leaf_nodes=3, max_depth=1 ...................
# [CV]  max_features=3, max_leaf_nodes=3, max_depth=1, score=0.909113 -   0.0s
# [CV] max_features=3, max_leaf_nodes=3, max_depth=1 ...................
# [CV]  max_features=3, max_leaf_nodes=3, max_depth=1, score=0.443607 -   0.0s
# [CV] max_features=3, max_leaf_nodes=5, max_depth=1 ...................
# [CV]  max_features=3, max_leaf_nodes=5, max_depth=1, score=0.457568 -   0.0s
# [CV] max_features=3, max_leaf_nodes=5, max_depth=1 ...................
# [CV]  max_features=3, max_leaf_nodes=5, max_depth=1, score=0.906509 -   0.0s
# [CV] max_features=3, max_leaf_nodes=5, max_depth=1 ...................
# [CV]  max_features=3, max_leaf_nodes=5, max_depth=1, score=0.407459 -   0.0s
# [CV] max_features=4, max_leaf_nodes=2, max_depth=1 ...................
# [CV]  max_features=4, max_leaf_nodes=2, max_depth=1, score=0.496419 -   0.0s
# [CV] max_features=4, max_leaf_nodes=2, max_depth=1 ...................
# [CV]  max_features=4, max_leaf_nodes=2, max_depth=1, score=0.639456 -   0.0s
# [CV] max_features=4, max_leaf_nodes=2, max_depth=1 ...................
# [CV]  max_features=4, max_leaf_nodes=2, max_depth=1, score=0.763279 -   0.0s
# [CV] max_features=4, max_leaf_nodes=3, max_depth=1 ...................
# [CV]  max_features=4, max_leaf_nodes=3, max_depth=1, score=0.501689 -   0.0s
# [CV] max_features=4, max_leaf_nodes=3, max_depth=1 ...................
# [CV]  max_features=4, max_leaf_nodes=3, max_depth=1, score=0.909113 -   0.0s
# [CV] max_features=4, max_leaf_nodes=3, max_depth=1 ...................
# [CV]  max_features=4, max_leaf_nodes=3, max_depth=1, score=0.443607 -   0.0s
# [CV] max_features=4, max_leaf_nodes=5, max_depth=1 ...................
# [CV]  max_features=4, max_leaf_nodes=5, max_depth=1, score=0.493243 -   0.0s
# [CV] max_features=4, max_leaf_nodes=5, max_depth=1 ...................
# [CV]  max_features=4, max_leaf_nodes=5, max_depth=1, score=0.906509 -   0.0s
# [CV] max_features=4, max_leaf_nodes=5, max_depth=1 ...................
# [CV]  max_features=4, max_leaf_nodes=5, max_depth=1, score=0.407459 -   0.0s
# [CV] max_features=1, max_leaf_nodes=2, max_depth=2 ...................
# [CV]  max_features=1, max_leaf_nodes=2, max_depth=2, score=-1.664076 -   0.0s
# [CV] max_features=1, max_leaf_nodes=2, max_depth=2 ...................
# [CV]  max_features=1, max_leaf_nodes=2, max_depth=2, score=-1.601765 -   0.0s
# [CV] max_features=1, max_leaf_nodes=2, max_depth=2 ...................
# [CV]  max_features=1, max_leaf_nodes=2, max_depth=2, score=0.763279 -   0.0s
# [CV] max_features=1, max_leaf_nodes=3, max_depth=2 ...................
# [CV]  max_features=1, max_leaf_nodes=3, max_depth=2, score=0.487973 -   0.0s
# [CV] max_features=1, max_leaf_nodes=3, max_depth=2 ...................
# [CV]  max_features=1, max_leaf_nodes=3, max_depth=2, score=0.753103 -   0.0s
# [CV] max_features=1, max_leaf_nodes=3, max_depth=2 ...................
# [CV]  max_features=1, max_leaf_nodes=3, max_depth=2, score=-0.313852 -   0.0s
# [CV] max_features=1, max_leaf_nodes=5, max_depth=2 ...................
# [CV]  max_features=1, max_leaf_nodes=5, max_depth=2, score=0.457568 -   0.0s
# [CV] max_features=1, max_leaf_nodes=5, max_depth=2 ...................
# [CV]  max_features=1, max_leaf_nodes=5, max_depth=2, score=0.354937 -   0.0s
# [CV] max_features=1, max_leaf_nodes=5, max_depth=2 ...................
# [CV]  max_features=1, max_leaf_nodes=5, max_depth=2, score=0.530410 -   0.0s
# [CV] max_features=2, max_leaf_nodes=2, max_depth=2 ...................
# [CV]  max_features=2, max_leaf_nodes=2, max_depth=2, score=0.496419 -   0.0s
# [CV] max_features=2, max_leaf_nodes=2, max_depth=2 ...................
# [CV]  max_features=2, max_leaf_nodes=2, max_depth=2, score=0.639456 -   0.0s
# [CV] max_features=2, max_leaf_nodes=2, max_depth=2 ...................
# [CV]  max_features=2, max_leaf_nodes=2, max_depth=2, score=0.763279 -   0.0s
# [CV] max_features=2, max_leaf_nodes=3, max_depth=2 ...................
# [CV]  max_features=2, max_leaf_nodes=3, max_depth=2, score=0.466014 -   0.0s
# [CV] max_features=2, max_leaf_nodes=3, max_depth=2 ...................
# [CV]  max_features=2, max_leaf_nodes=3, max_depth=2, score=0.636851 -   0.0s
# [CV] max_features=2, max_leaf_nodes=3, max_depth=2 ...................
# [CV]  max_features=2, max_leaf_nodes=3, max_depth=2, score=0.443607 -   0.0s
# [CV] max_features=2, max_leaf_nodes=5, max_depth=2 ...................
# [CV]  max_features=2, max_leaf_nodes=5, max_depth=2, score=0.496622 -   0.0s
# [CV] max_features=2, max_leaf_nodes=5, max_depth=2 ...................
# [CV]  max_features=2, max_leaf_nodes=5, max_depth=2, score=0.223938 -   0.0s
# [CV] max_features=2, max_leaf_nodes=5, max_depth=2 ...................
# [CV]  max_features=2, max_leaf_nodes=5, max_depth=2, score=0.530410 -   0.0s
# [CV] max_features=3, max_leaf_nodes=2, max_depth=2 ...................
# [CV]  max_features=3, max_leaf_nodes=2, max_depth=2, score=0.496419 -   0.0s
# [CV] max_features=3, max_leaf_nodes=2, max_depth=2 ...................
# [CV]  max_features=3, max_leaf_nodes=2, max_depth=2, score=0.639456 -   0.0s
# [CV] max_features=3, max_leaf_nodes=2, max_depth=2 ...................
# [CV]  max_features=3, max_leaf_nodes=2, max_depth=2, score=0.763279 -   0.0s
# [CV] max_features=3, max_leaf_nodes=3, max_depth=2 ...................
# [CV]  max_features=3, max_leaf_nodes=3, max_depth=2, score=0.501689 -   0.0s
# [CV] max_features=3, max_leaf_nodes=3, max_depth=2 ...................
# [CV]  max_features=3, max_leaf_nodes=3, max_depth=2, score=0.909113 -   0.0s
# [CV] max_features=3, max_leaf_nodes=3, max_depth=2 ...................
# [CV]  max_features=3, max_leaf_nodes=3, max_depth=2, score=0.443607 -   0.0s
# [CV] max_features=3, max_leaf_nodes=5, max_depth=2 ...................
# [CV]  max_features=3, max_leaf_nodes=5, max_depth=2, score=0.521757 -   0.0s
# [CV] max_features=3, max_leaf_nodes=5, max_depth=2 ...................
# [CV]  max_features=3, max_leaf_nodes=5, max_depth=2, score=0.223938 -   0.0s
# [CV] max_features=3, max_leaf_nodes=5, max_depth=2 ...................
# [CV]  max_features=3, max_leaf_nodes=5, max_depth=2, score=0.530410 -   0.0s
# [CV] max_features=4, max_leaf_nodes=2, max_depth=2 ...................
# [CV]  max_features=4, max_leaf_nodes=2, max_depth=2, score=0.496419 -   0.0s
# [CV] max_features=4, max_leaf_nodes=2, max_depth=2 ...................
# [CV]  max_features=4, max_leaf_nodes=2, max_depth=2, score=0.639456 -   0.0s
# [CV] max_features=4, max_leaf_nodes=2, max_depth=2 ...................
# [CV]  max_features=4, max_leaf_nodes=2, max_depth=2, score=0.763279 -   0.0s
# [CV] max_features=4, max_leaf_nodes=3, max_depth=2 ...................
# [CV]  max_features=4, max_leaf_nodes=3, max_depth=2, score=0.466014 -   0.0s
# [CV] max_features=4, max_leaf_nodes=3, max_depth=2 ...................
# [CV]  max_features=4, max_leaf_nodes=3, max_depth=2, score=0.909113 -   0.0s
# [CV] max_features=4, max_leaf_nodes=3, max_depth=2 ...................
# [CV]  max_features=4, max_leaf_nodes=3, max_depth=2, score=0.443607 -   0.0s
# [CV] max_features=4, max_leaf_nodes=5, max_depth=2 ...................
# [CV]  max_features=4, max_leaf_nodes=5, max_depth=2, score=0.560811 -   0.0s
# [CV] max_features=4, max_leaf_nodes=5, max_depth=2 ...................
# [CV]  max_features=4, max_leaf_nodes=5, max_depth=2, score=0.223938 -   0.0s
# [CV] max_features=4, max_leaf_nodes=5, max_depth=2 ...................
# [CV]  max_features=4, max_leaf_nodes=5, max_depth=2, score=0.530410 -   0.0s
# [CV] max_features=1, max_leaf_nodes=2, max_depth=3 ...................
# [Parallel(n_jobs=1)]: Done   1 tasks       | elapsed:    0.0s
# [Parallel(n_jobs=1)]: Done   4 tasks       | elapsed:    0.0s
# [Parallel(n_jobs=1)]: Done   7 tasks       | elapsed:    0.0s
# [Parallel(n_jobs=1)]: Done  12 tasks       | elapsed:    0.0s
# [Parallel(n_jobs=1)]: Done  17 tasks       | elapsed:    0.1s
# [Parallel(n_jobs=1)]: Done  24 tasks       | elapsed:    0.1s
# [Parallel(n_jobs=1)]: Done  31 tasks       | elapsed:    0.1s
# [Parallel(n_jobs=1)]: Done  40 tasks       | elapsed:    0.1s
# [Parallel(n_jobs=1)]: Done  49 tasks       | elapsed:    0.2s
# [Parallel(n_jobs=1)]: Done  60 tasks       | elapsed:    0.2s
# [Parallel(n_jobs=1)]: Done  71 tasks       | elapsed:    0.2s
# [CV]  max_features=1, max_leaf_nodes=2, max_depth=3, score=0.496419 -   0.0s
# [CV] max_features=1, max_leaf_nodes=2, max_depth=3 ...................
# [CV]  max_features=1, max_leaf_nodes=2, max_depth=3, score=0.639456 -   0.0s
# [CV] max_features=1, max_leaf_nodes=2, max_depth=3 ...................
# [CV]  max_features=1, max_leaf_nodes=2, max_depth=3, score=-0.873320 -   0.0s
# [CV] max_features=1, max_leaf_nodes=3, max_depth=3 ...................
# [CV]  max_features=1, max_leaf_nodes=3, max_depth=3, score=0.466014 -   0.0s
# [CV] max_features=1, max_leaf_nodes=3, max_depth=3 ...................
# [CV]  max_features=1, max_leaf_nodes=3, max_depth=3, score=0.357541 -   0.0s
# [CV] max_features=1, max_leaf_nodes=3, max_depth=3 ...................
# [CV]  max_features=1, max_leaf_nodes=3, max_depth=3, score=0.894426 -   0.0s
# [CV] max_features=1, max_leaf_nodes=5, max_depth=3 ...................
# [CV]  max_features=1, max_leaf_nodes=5, max_depth=3, score=0.457568 -   0.0s
# [CV] max_features=1, max_leaf_nodes=5, max_depth=3 ...................
# [CV]  max_features=1, max_leaf_nodes=5, max_depth=3, score=0.753103 -   0.0s
# [CV] max_features=1, max_leaf_nodes=5, max_depth=3 ...................
# [CV]  max_features=1, max_leaf_nodes=5, max_depth=3, score=0.530410 -   0.0s
# [CV] max_features=2, max_leaf_nodes=2, max_depth=3 ...................
# [CV]  max_features=2, max_leaf_nodes=2, max_depth=3, score=-0.749595 -   0.0s
# [CV] max_features=2, max_leaf_nodes=2, max_depth=3 ...................
# [CV]  max_features=2, max_leaf_nodes=2, max_depth=3, score=0.639456 -   0.0s
# [CV] max_features=2, max_leaf_nodes=2, max_depth=3 ...................
# [CV]  max_features=2, max_leaf_nodes=2, max_depth=3, score=0.084354 -   0.0s
# [CV] max_features=2, max_leaf_nodes=3, max_depth=3 ...................
# [CV]  max_features=2, max_leaf_nodes=3, max_depth=3, score=0.466014 -   0.0s
# [CV] max_features=2, max_leaf_nodes=3, max_depth=3 ...................
# [CV]  max_features=2, max_leaf_nodes=3, max_depth=3, score=0.357541 -   0.0s
# [CV] max_features=2, max_leaf_nodes=3, max_depth=3 ...................
# [CV]  max_features=2, max_leaf_nodes=3, max_depth=3, score=0.443607 -   0.0s
# [CV] max_features=2, max_leaf_nodes=5, max_depth=3 ...................
# [CV]  max_features=2, max_leaf_nodes=5, max_depth=3, score=0.560811 -   0.0s
# [CV] max_features=2, max_leaf_nodes=5, max_depth=3 ...................
# [CV]  max_features=2, max_leaf_nodes=5, max_depth=3, score=0.472146 -   0.0s
# [CV] max_features=2, max_leaf_nodes=5, max_depth=3 ...................
# [CV]  max_features=2, max_leaf_nodes=5, max_depth=3, score=0.590164 -   0.0s
# [CV] max_features=3, max_leaf_nodes=2, max_depth=3 ...................
# [CV]  max_features=3, max_leaf_nodes=2, max_depth=3, score=0.496419 -   0.0s
# [CV] max_features=3, max_leaf_nodes=2, max_depth=3 ...................
# [CV]  max_features=3, max_leaf_nodes=2, max_depth=3, score=0.639456 -   0.0s
# [CV] max_features=3, max_leaf_nodes=2, max_depth=3 ...................
# [CV]  max_features=3, max_leaf_nodes=2, max_depth=3, score=0.763279 -   0.0s
# [CV] max_features=3, max_leaf_nodes=3, max_depth=3 ...................
# [CV]  max_features=3, max_leaf_nodes=3, max_depth=3, score=0.466014 -   0.0s
# [CV] max_features=3, max_leaf_nodes=3, max_depth=3 ...................
# [CV]  max_features=3, max_leaf_nodes=3, max_depth=3, score=0.357541 -   0.0s
# [CV] max_features=3, max_leaf_nodes=3, max_depth=3 ...................
# [CV]  max_features=3, max_leaf_nodes=3, max_depth=3, score=0.894426 -   0.0s
# [CV] max_features=3, max_leaf_nodes=5, max_depth=3 ...................
# [CV]  max_features=3, max_leaf_nodes=5, max_depth=3, score=0.521757 -   0.0s
# [CV] max_features=3, max_leaf_nodes=5, max_depth=3 ...................
# [CV]  max_features=3, max_leaf_nodes=5, max_depth=3, score=0.906509 -   0.0s
# [CV] max_features=3, max_leaf_nodes=5, max_depth=3 ...................
# [CV]  max_features=3, max_leaf_nodes=5, max_depth=3, score=0.530410 -   0.0s
# [CV] max_features=4, max_leaf_nodes=2, max_depth=3 ...................
# [CV]  max_features=4, max_leaf_nodes=2, max_depth=3, score=0.496419 -   0.0s
# [CV] max_features=4, max_leaf_nodes=2, max_depth=3 ...................
# [CV]  max_features=4, max_leaf_nodes=2, max_depth=3, score=0.639456 -   0.0s
# [CV] max_features=4, max_leaf_nodes=2, max_depth=3 ...................
# [CV]  max_features=4, max_leaf_nodes=2, max_depth=3, score=0.763279 -   0.0s
# [CV] max_features=4, max_leaf_nodes=3, max_depth=3 ...................
# [CV]  max_features=4, max_leaf_nodes=3, max_depth=3, score=0.466014 -   0.0s
# [CV] max_features=4, max_leaf_nodes=3, max_depth=3 ...................
# [CV]  max_features=4, max_leaf_nodes=3, max_depth=3, score=0.909113 -   0.0s
# [CV] max_features=4, max_leaf_nodes=3, max_depth=3 ...................
# [CV]  max_features=4, max_leaf_nodes=3, max_depth=3, score=0.443607 -   0.0s
# [CV] max_features=4, max_leaf_nodes=5, max_depth=3 ...................
# [CV]  max_features=4, max_leaf_nodes=5, max_depth=3, score=0.521757 -   0.0s
# [CV] max_features=4, max_leaf_nodes=5, max_depth=3 ...................
# [CV]  max_features=4, max_leaf_nodes=5, max_depth=3, score=0.906509 -   0.0s
# [CV] max_features=4, max_leaf_nodes=5, max_depth=3 ...................
# [CV]  max_features=4, max_leaf_nodes=5, max_depth=3, score=0.530410 -   0.0s
# [CV] max_features=1, max_leaf_nodes=2, max_depth=4 ...................
# [CV]  max_features=1, max_leaf_nodes=2, max_depth=4, score=-1.664076 -   0.0s
# [CV] max_features=1, max_leaf_nodes=2, max_depth=4 ...................
# [CV]  max_features=1, max_leaf_nodes=2, max_depth=4, score=0.639456 -   0.0s
# [CV] max_features=1, max_leaf_nodes=2, max_depth=4 ...................
# [CV]  max_features=1, max_leaf_nodes=2, max_depth=4, score=0.763279 -   0.0s
# [CV] max_features=1, max_leaf_nodes=3, max_depth=4 ...................
# [CV]  max_features=1, max_leaf_nodes=3, max_depth=4, score=-1.510676 -   0.0s
# [CV] max_features=1, max_leaf_nodes=3, max_depth=4 ...................
# [CV]  max_features=1, max_leaf_nodes=3, max_depth=4, score=0.776391 -   0.0s
# [CV] max_features=1, max_leaf_nodes=3, max_depth=4 ...................
# [CV]  max_features=1, max_leaf_nodes=3, max_depth=4, score=0.894426 -   0.0s
# [CV] max_features=1, max_leaf_nodes=5, max_depth=4 ...................
# [CV]  max_features=1, max_leaf_nodes=5, max_depth=4, score=0.521757 -   0.0s
# [CV] max_features=1, max_leaf_nodes=5, max_depth=4 ...................
# [CV]  max_features=1, max_leaf_nodes=5, max_depth=4, score=0.885825 -   0.0s
# [CV] max_features=1, max_leaf_nodes=5, max_depth=4 ...................
# [CV]  max_features=1, max_leaf_nodes=5, max_depth=4, score=0.566475 -   0.0s
# [CV] max_features=2, max_leaf_nodes=2, max_depth=4 ...................
# [CV]  max_features=2, max_leaf_nodes=2, max_depth=4, score=0.496419 -   0.0s
# [CV] max_features=2, max_leaf_nodes=2, max_depth=4 ...................
# [CV]  max_features=2, max_leaf_nodes=2, max_depth=4, score=0.639456 -   0.0s
# [CV] max_features=2, max_leaf_nodes=2, max_depth=4 ...................
# [CV]  max_features=2, max_leaf_nodes=2, max_depth=4, score=0.763279 -   0.0s
# [CV] max_features=2, max_leaf_nodes=3, max_depth=4 ...................
# [CV]  max_features=2, max_leaf_nodes=3, max_depth=4, score=0.487973 -   0.0s
# [CV] max_features=2, max_leaf_nodes=3, max_depth=4 ...................
# [CV]  max_features=2, max_leaf_nodes=3, max_depth=4, score=0.357541 -   0.0s
# [CV] max_features=2, max_leaf_nodes=3, max_depth=4 ...................
# [CV]  max_features=2, max_leaf_nodes=3, max_depth=4, score=0.894426 -   0.0s
# [CV] max_features=2, max_leaf_nodes=5, max_depth=4 ...................
# [CV]  max_features=2, max_leaf_nodes=5, max_depth=4, score=0.496622 -   0.0s
# [CV] max_features=2, max_leaf_nodes=5, max_depth=4 ...................
# [CV]  max_features=2, max_leaf_nodes=5, max_depth=4, score=0.223938 -   0.0s
# [CV] max_features=2, max_leaf_nodes=5, max_depth=4 ...................
# [CV]  max_features=2, max_leaf_nodes=5, max_depth=4, score=0.557377 -   0.0s
# [CV] max_features=3, max_leaf_nodes=2, max_depth=4 ...................
# [CV]  max_features=3, max_leaf_nodes=2, max_depth=4, score=0.496419 -   0.0s
# [CV] max_features=3, max_leaf_nodes=2, max_depth=4 ...................
# [CV]  max_features=3, max_leaf_nodes=2, max_depth=4, score=0.639456 -   0.0s
# [CV] max_features=3, max_leaf_nodes=2, max_depth=4 ...................
# [CV]  max_features=3, max_leaf_nodes=2, max_depth=4, score=0.763279 -   0.0s
# [CV] max_features=3, max_leaf_nodes=3, max_depth=4 ...................
# [CV]  max_features=3, max_leaf_nodes=3, max_depth=4, score=0.501689 -   0.0s
# [CV] max_features=3, max_leaf_nodes=3, max_depth=4 ...................
# [CV]  max_features=3, max_leaf_nodes=3, max_depth=4, score=0.909113 -   0.0s
# [CV] max_features=3, max_leaf_nodes=3, max_depth=4 ...................
# [CV]  max_features=3, max_leaf_nodes=3, max_depth=4, score=0.443607 -   0.0s
# [CV] max_features=3, max_leaf_nodes=5, max_depth=4 ...................
# [CV]  max_features=3, max_leaf_nodes=5, max_depth=4, score=0.496622 -   0.0s
# [CV] max_features=3, max_leaf_nodes=5, max_depth=4 ...................
# [CV]  max_features=3, max_leaf_nodes=5, max_depth=4, score=0.223938 -   0.0s
# [CV] max_features=3, max_leaf_nodes=5, max_depth=4 ...................
# [CV]  max_features=3, max_leaf_nodes=5, max_depth=4, score=0.590164 -   0.0s
# [CV] max_features=4, max_leaf_nodes=2, max_depth=4 ...................
# [CV]  max_features=4, max_leaf_nodes=2, max_depth=4, score=0.496419 -   0.0s
# [CV] max_features=4, max_leaf_nodes=2, max_depth=4 ...................
# [CV]  max_features=4, max_leaf_nodes=2, max_depth=4, score=0.639456 -   0.0s
# [CV] max_features=4, max_leaf_nodes=2, max_depth=4 ...................
# [CV]  max_features=4, max_leaf_nodes=2, max_depth=4, score=0.763279 -   0.0s
# [CV] max_features=4, max_leaf_nodes=3, max_depth=4 ...................
# [CV]  max_features=4, max_leaf_nodes=3, max_depth=4, score=0.466014 -   0.0s
# [CV] max_features=4, max_leaf_nodes=3, max_depth=4 ...................
# [CV]  max_features=4, max_leaf_nodes=3, max_depth=4, score=0.357541 -   0.0s
# [CV] max_features=4, max_leaf_nodes=3, max_depth=4 ...................
# [CV]  max_features=4, max_leaf_nodes=3, max_depth=4, score=0.443607 -   0.0s
# [CV] max_features=4, max_leaf_nodes=5, max_depth=4 ...................
# [CV]  max_features=4, max_leaf_nodes=5, max_depth=4, score=0.521757 -   0.0s
# [CV] max_features=4, max_leaf_nodes=5, max_depth=4 ...................
# [CV]  max_features=4, max_leaf_nodes=5, max_depth=4, score=0.223938 -   0.0s
# [CV] max_features=4, max_leaf_nodes=5, max_depth=4 ...................
# [CV]  max_features=4, max_leaf_nodes=5, max_depth=4, score=0.530410 -   0.0s
# [Parallel(n_jobs=1)]: Done  84 tasks       | elapsed:    0.3s
# [Parallel(n_jobs=1)]: Done  97 tasks       | elapsed:    0.3s
# [Parallel(n_jobs=1)]: Done 112 tasks       | elapsed:    0.3s
# [Parallel(n_jobs=1)]: Done 127 tasks       | elapsed:    0.4s
# [Parallel(n_jobs=1)]: Done 144 tasks       | elapsed:    0.4s
# [Parallel(n_jobs=1)]: Done 144 out of 144 | elapsed:    0.4s finished
# GridSearchCV(cv=None, error_score='raise',
#        estimator=DecisionTreeRegressor(criterion='mse', max_depth=None, max_features=None,
#            max_leaf_nodes=None, min_samples_leaf=1, min_samples_split=2,
#            min_weight_fraction_leaf=0.0, presort=False, random_state=None,
#            splitter='best'),
#        fit_params={}, iid=True, n_jobs=1,
#        param_grid={'max_features': [1, 2, 3, 4], 'max_leaf_nodes': [2, 3, 5], 'max_depth': [1, 2, 3, 4]},
#        pre_dispatch='2*n_jobs', refit=True, scoring=None, verbose=10)

# %%
print grid_search.best_estimator_
print grid_search.best_params_
print grid_search.best_score_
# Out:
# DecisionTreeRegressor(criterion='mse', max_depth=1, max_features=2,
#            max_leaf_nodes=3, min_samples_leaf=1, min_samples_split=2,
#            min_weight_fraction_leaf=0.0, presort=False, random_state=None,
#            splitter='best')
# {'max_features': 2, 'max_leaf_nodes': 3, 'max_depth': 1}
# 0.766281159463

# %%
feature_names = ['year', 'miles', 'doors', 'is_car']

from IPython.display import Image
from sklearn.tree import export_graphviz
from sklearn.externals.six import StringIO
import pydot
dot_data = StringIO()  
export_graphviz(grid_search.best_estimator_, out_file=dot_data,  
                feature_names=feature_names,  
                filled=True, rounded=True,  
                special_characters=True)  
graph = pydot.graph_from_dot_data(dot_data.getvalue())  
Image(graph.create_png())

# %%
best_estimator = grid_search.best_estimator_
predictions = best_estimator.predict(X_test)
# Ignore max depth title for this one
make_pretty_plots(y_test, predictions, 0)

# %% [markdown]
# ## 4 Classification trees
#
# Classification trees are very similar to regression trees. Here is a quick comparison:
#
# |regression trees|classification trees|
# |---|---|
# |predict a continuous response|predict a categorical response|
# |predict using mean response of each leaf|predict using most commonly occuring class of each leaf|
# |splits are chosen to minimize MSE|splits are chosen to minimize a different criterion (discussed below)|
#
# Note that classification trees easily handle **more than two response classes**! (How have other classification models we've seen handled this scenario?)
#
# Here's an **example of a classification tree**, which predicts whether or not a patient who presented with chest pain has heart disease:

# %% [markdown]
# ### 4.a Building a classification tree in scikit-learn
# We'll build a classification tree using the [Car Dataset](./assets/datasets/cars.csv).
#
# - Load the dataset in pandas
# - Check for missing values
# - Encode all the categorical features to booleans using `pd.get_dummies`
# - Encode the labels using LabelEncoder
# - Split X and y with train_test split like above
#         train_test_split(X, y, test_size=0.3, random_state=42)
# - Fit a classification tree with `max_depth=3` on all data
# - Visualize the tree using graphviz
# - Compute the feature importances
# - Compute and display the confusion matrix
# - Release the constraint of `max_depth=3` and see if the classification improves

# %% [markdown]
# ## Bonus
#
# Visualize the last tree. Can you make sense of it? What does this teach you about decision tree interpretability?
