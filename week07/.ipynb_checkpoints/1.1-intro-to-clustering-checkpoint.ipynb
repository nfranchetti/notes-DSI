# %% [markdown]
# ### Section I: Import the data

# %%
# %matplotlib inline 

import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
iris = pd.read_csv("../../DSI-CHI-1/lessons/week-07/1.1-intro-to-clustering/assets/datasets/iris.csv")
iris.head()
# Out:
#    SepalLength  SepalWidth  PetalLength  PetalWidth         Name
# 0          5.1         3.5          1.4         0.2  Iris-setosa
# 1          4.9         3.0          1.4         0.2  Iris-setosa
# 2          4.7         3.2          1.3         0.2  Iris-setosa
# 3          4.6         3.1          1.5         0.2  Iris-setosa
# 4          5.0         3.6          1.4         0.2  Iris-setosa

# %% [markdown]
# ### Plot the Data

# %%
sns.pairplot(iris)

# %% [markdown]
# ### Extract the features you to use in clustering into a matrix

# %%
from sklearn.preprocessing import StandardScaler

standardized_features = StandardScaler().fit_transform(iris.drop('Name', axis=1))

# %%
standardized_features.shape
# Out:
# (150, 4)

# %% [markdown]
# ### Cluster the data using K-Means Clustering

# %% [markdown]
# Cluster two of the variables of your choice. Choose K based on your plots and the behavior of the data

# %%
from sklearn.cluster import KMeans

kmeans = KMeans(2)
kmeans
# Out:
# KMeans(copy_x=True, init='k-means++', max_iter=300, n_clusters=2, n_init=10,
#     n_jobs=1, precompute_distances='auto', random_state=None, tol=0.0001,
#     verbose=0)

# %%
kmeans.fit(standardized_features)
predictions = kmeans.predict(standardized_features)

# %%
petals = iris[['PetalWidth', 'PetalLength']].copy()

# %%
petals
# Out:
#      PetalWidth  PetalLength
# 0           0.2          1.4
# 1           0.2          1.4
# 2           0.2          1.3
# 3           0.2          1.5
# 4           0.2          1.4
# 5           0.4          1.7
# 6           0.3          1.4
# 7           0.2          1.5
# 8           0.2          1.4
# 9           0.1          1.5
# 10          0.2          1.5
# 11          0.2          1.6
# 12          0.1          1.4
# 13          0.1          1.1
# 14          0.2          1.2
# 15          0.4          1.5
# 16          0.4          1.3
# 17          0.3          1.4
# 18          0.3          1.7
# 19          0.3          1.5
# 20          0.2          1.7
# 21          0.4          1.5
# 22          0.2          1.0
# 23          0.5          1.7
# 24          0.2          1.9
# 25          0.2          1.6
# 26          0.4          1.6
# 27          0.2          1.5
# 28          0.2          1.4
# 29          0.2          1.6
# ..          ...          ...
# ...

# %% [markdown]
# ### Find the Silhoutte Score and plot the features and clusters
