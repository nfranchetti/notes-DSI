# %% [markdown]
# ### KNN (K-Nearest Neighbors Classification)

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
# %matplotlib inline

import seaborn as sns

from sklearn.neighbors import KNeighborsClassifier

# %%
X = [[0], [1], [2], [3]]
y = [0, 0, 1, 1]

# %%
neigh = KNeighborsClassifier(n_neighbors=3)
neigh
# Out:
# KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='minkowski',
#            metric_params=None, n_jobs=1, n_neighbors=3, p=2,
#            weights='uniform')

# %%
neigh.fit(X, y)
# Out:
# KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='minkowski',
#            metric_params=None, n_jobs=1, n_neighbors=3, p=2,
#            weights='uniform')

# %%
new_point = [1.1]
neigh.predict(new_point)
# Out:
# /home/nick/anaconda2/lib/python2.7/site-packages/sklearn/utils/validation.py:386: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and willraise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   DeprecationWarning)
# array([0])

# %%
neigh.predict_proba(new_point)
# Out:
# /home/nick/anaconda2/lib/python2.7/site-packages/sklearn/utils/validation.py:386: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and willraise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   DeprecationWarning)
# array([[ 0.66666667,  0.33333333]])

# %% [markdown]
# #### Load in the Wisconsin breast cancer dataset. The attributes below will be the columns of the dataset.
#
# Attribute Information: (class attribute has been moved to last column)
#
#       Attribute                     Values
#    -- -----------------------------------------
#    1. Sample code number            id number
#    2. Clump Thickness               1 - 10
#    3. Uniformity of Cell Size       1 - 10
#    4. Uniformity of Cell Shape      1 - 10
#    5. Marginal Adhesion             1 - 10
#    6. Single Epithelial Cell Size   1 - 10
#    7. Bare Nuclei                   1 - 10
#    8. Bland Chromatin               1 - 10
#    9. Normal Nucleoli               1 - 10
#    10. Mitoses                       1 - 10
#    11. Class:                        (2 for benign, 4 for malignant)

# %% [markdown]
# The column names are taken from the dataset info file. Create an array
# with the column names and assign them as the header when loading the
# csv.

# %%
names = ['id_num',
        'clump_thickness',
        'uniformity_cell_size',
        'uniformity_cell_shape',
        'marginal_adhesion',
        'epithelial_cell_size',
        'bare_nuclei',
        'bland_chromatin',
        'normal_nucleoli',
        'mitoses',
        'class']

# %%
data = pd.read_csv('breast-cancer-wisconsin.csv', names=names)
data.head()
# Out:
#     id_num  clump_thickness  uniformity_cell_size  uniformity_cell_shape  \
# 0  1000025                5                     1                      1
# 1  1002945                5                     4                      4
# 2  1015425                3                     1                      1
# 3  1016277                6                     8                      8
# 4  1017023                4                     1                      1
#
#    marginal_adhesion  epithelial_cell_size bare_nuclei  bland_chromatin  \
# 0                  1                     2           1                3
# 1                  5                     7          10                3
# 2                  1                     2           2                3
# 3                  1                     3           4                3
# 4                  3                     2           1                3
#
#    normal_nucleoli  mitoses  class
# 0                1        1      2
# 1                2        1      2
# 2                1        1      2
# 3                7        1      2
# 4                1        1      2

# %% [markdown]
# The class field is coded as "2" for benign and "4" as malignant.
# - Let's recode this to a binary variable for classification, with "1" as malign and "0" as benign.

# %%
# Fill in code!
data['class'] = data['class'].apply(lambda x: 1 if x == 4 else 0)
data['class'].describe()
# Out:
# count    699.000000
# mean       0.344778
# std        0.475636
# min        0.000000
# 25%        0.000000
# 50%        0.000000
# 75%        1.000000
# max        1.000000
# Name: class, dtype: float64

# %% [markdown]
# Look at the data using seaborn's "pairplot" function. First put the dataset into "long" format, which seaborn requires for it's plotting functions:

# %%
# Fill in code!
sns.pairplot(data)

# %% [markdown]
# It's very useful and recommended to look at the correlation matrix:

# %%
# Fill in code!
data.corr()
# Out:
#                          id_num  clump_thickness  uniformity_cell_size  \
# id_num                 1.000000        -0.055308             -0.041603
# clump_thickness       -0.055308         1.000000              0.644913
# uniformity_cell_size  -0.041603         0.644913              1.000000
# uniformity_cell_shape -0.041576         0.654589              0.906882
# marginal_adhesion     -0.064878         0.486356              0.705582
# epithelial_cell_size  -0.045528         0.521816              0.751799
# bland_chromatin       -0.060051         0.558428              0.755721
# normal_nucleoli       -0.052072         0.535835              0.722865
# mitoses               -0.034901         0.350034              0.458693
# class                 -0.080226         0.716001              0.817904
#
#                        uniformity_cell_shape  marginal_adhesion  \
# id_num                             -0.041576          -0.064878
# clump_thickness                     0.654589           0.486356
# uniformity_cell_size                0.906882           0.705582
# uniformity_cell_shape               1.000000           0.683079
# marginal_adhesion                   0.683079           1.000000
# epithelial_cell_size                0.719668           0.599599
# bland_chromatin                     0.735948           0.666715
# normal_nucleoli                     0.719446           0.603352
# mitoses                             0.438911           0.417633
# class                               0.818934           0.696800
#
#                        epithelial_cell_size  bland_chromatin  normal_nucleoli  \
# id_num                            -0.045528        -0.060051        -0.052072
# clump_thickness                    0.521816         0.558428         0.535835
# uniformity_cell_size               0.751799         0.755721         0.722865
# uniformity_cell_shape              0.719668         0.735948         0.719446
# marginal_adhesion                  0.599599         0.666715         0.603352
# epithelial_cell_size               1.000000         0.616102         0.628881
# bland_chromatin                    0.616102         1.000000         0.665878
# normal_nucleoli                    0.628881         0.665878         1.000000
# mitoses                            0.479101         0.344169         0.428336
# class                              0.682785         0.756616         0.712244
#
#                         mitoses     class
# id_num                -0.034901 -0.080226
# clump_thickness        0.350034  0.716001
# uniformity_cell_size   0.458693  0.817904
# uniformity_cell_shape  0.438911  0.818934
# marginal_adhesion      0.417633  0.696800
# epithelial_cell_size   0.479101  0.682785
# bland_chromatin        0.344169  0.756616
# normal_nucleoli        0.428336  0.712244
# mitoses                1.000000  0.423170
# class                  0.423170  1.000000

# %%
data.corr().loc[:, 'class']
# Out:
# id_num                  -0.080226
# clump_thickness          0.716001
# uniformity_cell_size     0.817904
# uniformity_cell_shape    0.818934
# marginal_adhesion        0.696800
# epithelial_cell_size     0.682785
# bland_chromatin          0.756616
# normal_nucleoli          0.712244
# mitoses                  0.423170
# class                    1.000000
# Name: class, dtype: float64

# %%
data[['class', 'uniformity_cell_size', 'uniformity_cell_shape', 'bland_chromatin']].corr()
# Out:
#                           class  uniformity_cell_size  uniformity_cell_shape  \
# class                  1.000000              0.817904               0.818934
# uniformity_cell_size   0.817904              1.000000               0.906882
# uniformity_cell_shape  0.818934              0.906882               1.000000
# bland_chromatin        0.756616              0.755721               0.735948
#
#                        bland_chromatin
# class                         0.756616
# uniformity_cell_size          0.755721
# uniformity_cell_shape         0.735948
# bland_chromatin               1.000000

# %% [markdown]
# Most of these predictors are highly correlated with the "class" variable. This is already an indication that our classifier is very likely to perform well.
#
# We can plot out in detail how the classes distribute across the variables using the very useful pairplot() function from seaborn:

# %%
# Fill in code!

# %% [markdown]
# Let's see how the kNN classifier performs on the dataset (using cross-validation).
#
# We are going to set some parameters in the classifier constructor. Some clarification below:
#
# 1. **n_neighbors** specifies how many neighbors will vote on the class
# 2. **weights** uniform weights indicate that all neighbors have the same weight
# 3. **metric** and **p** when distance is minkowski (the default) and p == 2 (the default), this is equivalent to the euclidean distance metric
#
# Also load scikit's handy cross-validation module and perform the crossval

# %%
# Fill in code!
y = data['class']
X = data[['uniformity_cell_size', 'uniformity_cell_shape', 'bland_chromatin']]

knn = KNeighborsClassifier(n_neighbors=5)
knn.fit(X, y)
print knn.score(X, y)
# Out:
# 0.9556509299

# %%
new_point = [[2, 8, 2]]
knn.predict_proba(new_point)
# Out:
# array([[ 0.2,  0.8]])

# %%
# Fill in code!

# %% [markdown]
# - As you can see the accuracy is very high with 5 neighbors. [NOTE: ask what might be wrong with accuracy as a metric here].
#
# - Let's see what it's like when we use only 1 neighbor:

# %%
# Fill in code!

# %% [markdown]
# - Even with 1 neighbor we do quite well at predicting the malignant observations.
#
# - Now fit a kNN classifier with n_neighbors=5 using just 'clump thickness' and 'cell size uniformity' as variables.
#
# - Plot the points and the colors of where the classifier decides between malignant vs. benign. The size of the circles denotes the number of observations at that point. The hue of the circle denotes the mixture of class labels between 0 and 1.

# %%
# Fill in code!
